# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('nepal_stock_market.csv')
df
# Out:
#       published_date   open   high    low   close  per_change  \
# 0         2022-01-02  410.0  412.0  400.1  411.00        0.24
# 1         2022-01-03  416.0  418.0  412.0  415.00        0.97
# 2         2022-01-04  422.0  424.0  410.0  422.00        1.69
# 3         2022-01-05  426.0  430.0  418.0  419.00       -0.71
# 4         2022-01-06  420.0  422.0  415.5  421.00        0.48
# ...              ...    ...    ...    ...     ...         ...
# 83266     2025-04-20  200.3  208.0  200.0  200.58       -1.83
# 83267     2025-04-21  204.5  204.5  199.8  200.75        0.08
# 83268     2025-04-22  200.2  202.4  199.0  199.73       -0.51
# 83269     2025-04-23  201.7  201.7  197.0  197.51       -1.11
# 83270     2025-04-24  197.0  199.0  196.2  197.18       -0.17
#
#        traded_quantity  traded_amount  status Company
# 0              78818.0     32071339.8       1    ADBL
# 1              35929.0     14924061.5       1    ADBL
# 2              52990.0     22249267.5       1    ADBL
# 3              45591.0     19202068.3      -1    ADBL
# 4              37485.0     15665637.0       1    ADBL
# ...                ...            ...     ...     ...
# 83266         147677.0     29700844.0       1   UPPER
# 83267         166506.0     33610335.5      -1   UPPER
# 83268         144020.0     28809857.6      -1   UPPER
# 83269         140211.0     27766853.3      -1   UPPER
# 83270         117888.0     23262601.4       1   UPPER
#
# [83271 rows x 10 columns]

# %%
df['published_date'] = pd.to_datetime(df['published_date'])
df['weekday'] = df['published_date'].dt.day_name()
df['month'] = df['published_date'].dt.month
df['week'] = df['published_date'].dt.isocalendar().week
df = df.sort_values('published_date')

# %%
df['Company'].unique()
# Out:
# array(['ADBL', 'LBBL', 'NRN', 'KSBBL', 'NYADI', 'KRBL', 'OHL', 'ALICL',
#        'UMRH', 'KPCL', 'PCBL', 'KKHC', 'AHPC', 'PFL', 'PLI', 'JOSHI',
#        'JLI', 'PLIC', 'TPC', 'BOKL', 'PMHPL', 'JFL', 'PPCL', 'JBBL',
#        'PROFL', 'KBL', 'UPPER', 'NMB', 'LBL', 'API', 'MNBBL', 'NCCB',
#        'MLBL', 'NFS', 'MKJC', 'NGPL', 'MHNL', 'NHDL', 'MFIL', 'NHPC',
#        'ULI', 'BARUN', 'MEN', 'MEGA', 'NICA', 'MDB', 'NIFRA', 'MBL',
#        'NLIC', 'LICN', 'NLICL', 'TRH', 'BFC', 'LEC', 'BPCL', 'ICFC',
#        'PRVU', 'HURJA', 'SFCL', 'SRBL', 'CGH', 'GBBL', 'SHEL', 'EDBL',
#        'SHINE', 'UNHPL', 'AKPL', 'EBL', 'SHL', 'DHPL', 'SHPC', 'SPDL',
#        'CHCL', 'CZBIL', 'SIFC', 'CORBL', 'SINDU', 'CIT', 'SJCL', 'CHL',
#        'SLI', 'CHDC', 'SLICL', 'GBIME', 'UMHL', 'SCB', 'SBL', 'RADHI',
#        'HPPL', 'RHPL', 'UPCL', 'AKJCL', 'HIDCL', 'RLFL', 'SSHL', 'CBL',
#        'HDHPC', 'RLI', 'RURU', 'SADBL', 'GUFL', 'CCBL', 'SAHAS', 'GRDBL',
#        'SANIMA', 'GMFIL', 'GLICL', 'CFCL', 'SAPDBL', 'GLH', 'SBI', 'GHL',
#        'GFCL', 'NBL', 'SPC', 'MPFL', 'NABBC', 'NABIL', 'NBB', 'NIB',
#        'HBL'], dtype=object)

# %%
{
  "Commercial Bank": [
    "ADBL",
    "BOKL",
    "CBL",
    "CCBL",
    "CZBIL",
    "EBL",
    "GBIME",
    "HBL",
    "KBL",
    "LBL",
    "MBL",
    "MEGA",
    "NABIL",
    "NBB",
    "NBL",
    "NCCB",
    "NIB",
    "NICA",
    "NMB",
    "PCBL",
    "PRVU",
    "SANIMA",
    "SBI",
    "SBL",
    "SCB",
    "SRBL"
  ],
  "Development Bank": [
    "CORBL",
    "EDBL",
    "GBBL",
    "GRDBL",
    "JBBL",
    "KRBL",
    "KSBBL",
    "MDB",
    "MLBL",
    "MNBBL",
    "NABBC",
    "SADBL",
    "SAPDBL",
    "SHINE",
    "SINDU"
  ],
  "Finance": [
    "BFC",
    "CFCL",
    "GFCL",
    "GMFIL",
    "GUFL",
    "ICFC",
    "JFL",
    "MFIL",
    "MPFL",
    "NFS",
    "PFL",
    "PROFL",
    "RLFL",
    "SFCL",
    "SIFC",
    "ULI"
  ],
  "Hydropower": [
    "AHPC",
    "AKJCL",
    "AKPL",
    "API",
    "BARUN",
    "CHCL",
    "CHDC",
    "DHPL",
    "GHL",
    "GLH",
    "HDHPC",
    "HIDCL",
    "HPPL",
    "HURJA",
    "JOSHI",
    "KKHC",
    "KPCL",
    "LEC",
    "MEN",
    "MHNL",
    "MKJC",
    "NGPL",
    "NHDL",
    "NHPC",
    "OHL",
    "PMHPL",
    "PPCL",
    "RADHI",
    "RHPL",
    "RURU",
    "SAHAS",
    "SHEL",
    "SHL",
    "SHPC",
    "SJCL",
    "SPC",
    "SPDL",
    "SSHL",
    "TPC",
    "UMHL",
    "UMRH",
    "UNHPL",
    "UPCL",
    "UPPER"
  ],
  "Life Insurance": [
    "ALICL",
    "GLICL",
    "JLI",
    "LICN",
    "NLIC",
    "NLICL",
    "PLI",
    "PLIC",
    "RLI",
    "SLI",
    "SLICL"
  ],
  "Microfinance": [
    "NYADI"
  ],
  "Hotels and Tourism": [
    "CGH",
    "TRH"
  ],
  "Investment": [
    "CIT",
    "NIFRA",
    "NRN"
  ]
}
# Out:
# {'Commercial Bank': ['ADBL',
#   'BOKL',
#   'CBL',
#   'CCBL',
#   'CZBIL',
#   'EBL',
#   'GBIME',
#   'HBL',
#   'KBL',
#   'LBL',
#   'MBL',
#   'MEGA',
#   'NABIL',
#   'NBB',
#   'NBL',
#   'NCCB',
#   'NIB',
#   'NICA',
#   'NMB',
#   'PCBL',
#   'PRVU',
#   'SANIMA',
#   'SBI',
#   'SBL',
#   'SCB',
#   'SRBL'],
#  'Development Bank': ['CORBL',
#   'EDBL',
#   'GBBL',
#   'GRDBL',
#   'JBBL',
#   'KRBL',
#   'KSBBL',
#   'MDB',
#   'MLBL',
#   'MNBBL',
#   'NABBC',
#   'SADBL',
#   'SAPDBL',
#   'SHINE',
#   'SINDU'],
#  'Finance': ['BFC',
#   'CFCL',
#   'GFCL',
#   'GMFIL',
#   'GUFL',
#   'ICFC',
#   'JFL',
#   'MFIL',
#   'MPFL',
#   'NFS',
#   'PFL',
#   'PROFL',
#   'RLFL',
#   'SFCL',
#   'SIFC',
#   'ULI'],
#  'Hydropower': ['AHPC',
#   'AKJCL',
#   'AKPL',
#   'API',
#   'BARUN',
#   'CHCL',
#   'CHDC',
#   'DHPL',
#   'GHL',
#   'GLH',
#   'HDHPC',
#   'HIDCL',
#   'HPPL',
#   'HURJA',
#   'JOSHI',
#   'KKHC',
#   'KPCL',
#   'LEC',
#   'MEN',
#   'MHNL',
#   'MKJC',
#   'NGPL',
#   'NHDL',
#   'NHPC',
#   'OHL',
#   'PMHPL',
#   'PPCL',
#   'RADHI',
#   'RHPL',
#   'RURU',
#   'SAHAS',
#   'SHEL',
#   'SHL',
#   'SHPC',
#   'SJCL',
#   'SPC',
#   'SPDL',
#   'SSHL',
#   'TPC',
#   'UMHL',
#   'UMRH',
#   'UNHPL',
#   'UPCL',
#   'UPPER'],
#  'Life Insurance': ['ALICL',
#   'GLICL',
#   'JLI',
#   'LICN',
#   'NLIC',
#   'NLICL',
#   'PLI',
#   'PLIC',
#   'RLI',
#   'SLI',
#   'SLICL'],
#  'Microfinance': ['NYADI'],
#  'Hotels and Tourism': ['CGH', 'TRH'],
#  'Investment': ['CIT', 'NIFRA', 'NRN']}

# %%
commercial_banks = [
    'ADBL', 'BOKL', 'EBL', 'HBL', 'KBL', 'MEGA', 'MBL', 'NABIL', 'NBB',
    'NBL', 'NIB', 'NMB', 'PCBL', 'PRVU', 'SANIMA', 'SCB', 'SBL', 'SBI',
    'SRBL', 'NICA', 'GBIME', 'CCBL'
]

development_banks = [
    'LBBL', 'MLBL', 'MNBBL', 'NCCB', 'SINDU', 'SHINE', 'KSBBL', 'GBBL', 'CZBIL', 'CBL', 'GRDBL'
]

finance_companies = [
    'BFC', 'CFCL', 'GMFIL', 'GUFL', 'ICFC', 'JFL', 'MPFL', 'PFL',
    'PROFL', 'RLFL', 'SFCL', 'SIFC', 'MDB', 'NFS', 'GFCL'
]

microfinance = [
    'AKJCL', 'KRBL', 'LEC', 'MKJC', 'NABBC', 'SAPDBL', 'SSHL', 'UMRH'
]

hydropower = [
    'AHPC', 'AKPL', 'API', 'BARUN', 'BPCL', 'CHCL', 'CHDC', 'CHL', 'DHPL', 'EDBL',
    'GHL', 'HIDCL', 'HPPL', 'HURJA', 'JOSHI', 'KKHC', 'MEN', 'MHNL', 'NHDL', 'NHPC',
    'NGPL', 'NYADI', 'PMHPL', 'PPCL', 'RADHI', 'RHPL', 'RURU', 'SAHAS', 'SHEL', 'SHL',
    'SHPC', 'SJCL', 'SPC', 'SPDL', 'TPC', 'ULI', 'UMHL', 'UNHPL', 'UPCL', 'UPPER', 'GLH'
]

life_insurance = [
    'ALICL', 'GLICL', 'JLI', 'LICN', 'NLIC', 'NLICL', 'PLIC', 'RLI', 'SLICL', 'SLI'
]

non_life_insurance = [
    'PLI'
]

investment = [
    'CIT', 'CORBL'
]

hotels_and_tourism = [
    'TRH', 'OHL', 'CGH'
]

nepse_sectors = {
    'Commercial Banks': commercial_banks,
    'Development Banks': development_banks,
    'Finance Companies': finance_companies,
    'Microfinance': microfinance,
    'Hydropower': hydropower,
    'Life Insurance': life_insurance,
    'Non-Life Insurance': non_life_insurance,
    'Investment': investment,
    'Hotels and Tourism': hotels_and_tourism,
}

# %%
df_commercial = df[df['Company'].isin(commercial_banks)]

top5 = df_commercial['Company'].value_counts().head(5).index.tolist()

df_top5 = df_commercial[df_commercial['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for Top 5 Commercial Banks')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
development_banks = [
    'LBBL', 'MLBL', 'MNBBL', 'NCCB', 'SINDU', 'SHINE', 'KSBBL', 'GBBL', 'CZBIL', 'CBL', 'GRDBL'
]

df_dev_banks = df[df['Company'].isin(development_banks)].copy()

plt.figure(figsize=(14, 8))
sns.lineplot(data=df_dev_banks, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for Development Banks')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
finance_companies = [
    'BFC', 'CFCL', 'GMFIL', 'GUFL', 'ICFC', 'JFL', 'MPFL', 'PFL',
    'PROFL', 'RLFL', 'SFCL', 'SIFC', 'MDB', 'NFS', 'GFCL'
]

df_finance = df[df['Company'].isin(finance_companies)]

top5 = df_finance['Company'].value_counts().head(5).index.tolist()

df_top5 = df_finance[df_finance['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for Top 5 Finance Companies')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_microfinance = df[df['Company'].isin(microfinance)]

top5 = df_microfinance['Company'].value_counts().index.tolist()

df_top5 = df_microfinance[df_microfinance['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for microfinance Companies')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_hydro = df[df['Company'].isin(hydropower)]

top5 = df_hydro['Company'].value_counts().index.tolist()

df_top5 = df_hydro[df_hydro['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for  Hydropower Companies')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_life = df[df['Company'].isin(life_insurance)]

top5 = df_life['Company'].value_counts().index.tolist()

df_top5 = df_life[df_life['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for Life Insurance Companies')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_non_life_insurance = df[df['Company'].isin(non_life_insurance)]

top5 = df_non_life_insurance['Company'].value_counts().index.tolist()

df_top5 = df_non_life_insurance[df_non_life_insurance['Company'].isin(top5)]

plt.figure(figsize=(14,8))
sns.lineplot(data=df_top5, x='published_date', y='close', hue='Company')
plt.title('Closing Price Over Time for Non Life Insurance Companies')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # I. Imputation for Missing Values

# %%
df.isna().sum()
# Out:
# published_date        0
# open                850
# high                  0
# low                   0
# close                 0
# per_change         2000
# traded_quantity       0
# traded_amount      1560
# status                0
# Company               0
# weekday               0
# month                 0
# week                  0
# dtype: int64

# %%
df['published_date'] = pd.to_datetime(df['published_date'])
df = df.sort_values('published_date')

# %%
df = df.sort_values(['Company', 'published_date'])
df['open'] = df['open'].fillna(df.groupby('Company')['close'].shift(1))

# %%
df['traded_amount'] = df['traded_amount'].fillna(df['traded_quantity'] * df['close'])
df.isna().sum()
# Out:
# published_date        0
# open                  1
# high                  0
# low                   0
# close                 0
# per_change         2000
# traded_quantity       0
# traded_amount         0
# status                0
# Company               0
# weekday               0
# month                 0
# week                  0
# dtype: int64

# %%
df['per_change'] = df['per_change'].fillna(((df['high'] - df['low']) / df['high']) * 100)
df.isna().sum()
# Out:
# published_date     0
# open               1
# high               0
# low                0
# close              0
# per_change         0
# traded_quantity    0
# traded_amount      0
# status             0
# Company            0
# weekday            0
# month              0
# week               0
# dtype: int64

# %%
df['open'] = df['open'].fillna(360)
df.isna().sum()
# Out:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         0
# traded_quantity    0
# traded_amount      0
# status             0
# Company            0
# weekday            0
# month              0
# week               0
# dtype: int64

# %% [markdown]
# #  How many unique companies are in the dataset? Which company has the most trading records?

# %%
df['Company'].nunique()
# Out:
# 121

# %%
df['Company'].value_counts().head(15)
# Out:
# Company
# ADBL     776
# AHPC     776
# AKJCL    776
# AKPL     776
# ALICL    776
# API      776
# BARUN    776
# BFC      776
# BPCL     776
# EBL      776
# CHDC     776
# CHCL     776
# CGH      776
# CHL      776
# CZBIL    776
# Name: count, dtype: int64

# %% [markdown]
# # What are the average, minimum, and maximum values for open, close, traded_amount, and per_change?

# %%
df[['open','close','traded_amount','per_change']].describe().loc[['mean','min','max']]
# Out:
#             open       close  traded_amount  per_change
# mean   430.87796   430.26261   2.264881e+07    0.148121
# min    118.00000   117.10000   2.070000e+03  -10.000000
# max   3608.70000  3575.00000   1.582512e+09   16.127673

# %% [markdown]
# # What is the distribution of daily percent change (per_change)? Are there more gain days or loss days?

# %%
gain_days = (df['per_change'] > 0).sum()
loss_days = (df['per_change'] < 0).sum()
print(f"Gain days: {gain_days}")
print(f"Loss days: {loss_days}")
# Out:
# Gain days: 36914
# Loss days: 43900

# %% [markdown]
# There are more loss days

# %% [markdown]
# # How frequently do companies have a positive (status = 1) vs negative (status = -1) performance?

# %%
df.groupby(['Company', 'status']).size().reset_index(name='count')
# Out:
#     Company  status  count
# 0      ADBL      -1    462
# 1      ADBL       0     29
# 2      ADBL       1    285
# 3      AHPC      -1    482
# 4      AHPC       0     15
# ..      ...     ...    ...
# 357    UPCL       0     26
# 358    UPCL       1    280
# 359   UPPER      -1    486
# 360   UPPER       0     20
# 361   UPPER       1    270
#
# [362 rows x 3 columns]

# %% [markdown]
# # Are there any correlations between features like open, high, low, close, and traded_amount?

# %%
features = ['open', 'high', 'low', 'close', 'traded_amount']
corr_matrix = df[features].corr()
corr_matrix
# Out:
#                    open      high       low     close  traded_amount
# open           1.000000  0.999224  0.999287  0.998807       0.231062
# high           0.999224  1.000000  0.998834  0.999484       0.241470
# low            0.999287  0.998834  1.000000  0.999027       0.226420
# close          0.998807  0.999484  0.999027  1.000000       0.236208
# traded_amount  0.231062  0.241470  0.226420  0.236208       1.000000

# %% [markdown]
# # What are the top 5 days with the highest trading volume and how did the prices behave on those days?

# %%
df.sort_values(by='traded_quantity', ascending=False).head(5)
# Out:
#       published_date   open   high    low   close  per_change  \
# 49879     2024-08-08  285.0  311.3  280.0  307.50        8.66
# 83016     2024-03-14  180.0  190.7  170.0  187.90        2.34
# 25219     2025-04-17  663.0  711.0  600.0  667.89        0.89
# 29803     2024-08-18  261.1  272.9  253.0  259.00        1.17
# 29790     2024-07-29  216.6  233.5  216.6  222.00        4.52
#
#        traded_quantity  traded_amount  status Company   weekday  month  week
# 49879        3037821.0   9.246939e+08       1   NIFRA  Thursday      8    32
# 83016        2768765.0   5.089081e+08       1   UPPER  Thursday      3    11
# 25219        2531957.0   1.582512e+09       1    HPPL  Thursday      4    16
# 29803        2489844.0   6.593896e+08      -1     KBL    Sunday      8    33
# 29790        2463069.0   5.522761e+08       1     KBL    Monday      7    31

# %% [markdown]
# # Are there any missing values in the dataset? In which columns are they most common, and how might that affect analysis?
#
# Missing data are mostly common in open, per_change, and traded_amount. These can be filled or recalculated using other columns.

# %% [markdown]
# # Which companies experienced the highest average daily percent increase/decrease over time?

# %%
df.groupby('Company')['per_change'].mean().sort_values(ascending=False).head(5)
# Out:
# Company
# NBB      0.598848
# GRDBL    0.395646
# CORBL    0.383733
# NABBC    0.376664
# NRN      0.326840
# Name: per_change, dtype: float64

# %%
df.groupby('Company')['per_change'].mean().sort_values(ascending=False).tail(10)
# Out:
# Company
# SRBL    -0.046099
# RLI     -0.055183
# LBL     -0.066658
# JLI     -0.123045
# GLICL   -0.127232
# BOKL    -0.149393
# ULI     -0.206392
# PLIC    -0.307304
# SLICL   -0.329394
# NIB     -0.897701
# Name: per_change, dtype: float64

# %% [markdown]
# # II. EDA Questions for Stock Dataset
# 1. Time Series / Line Plot Focused Questions

# %% [markdown]
# # How has the closing price changed over time for a specific company (e.g., ADBL or UPPER)?

# %%
company_df = df[df['Company']=='ADBL']

company_df = company_df.sort_values(by='published_date')

plt.figure(figsize=(12, 6))
plt.plot(company_df['published_date'], company_df['close'], label='Close Price', color='blue')
plt.title('Closing Price Over Time - ADBL')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Compare the opening and closing prices over time for one company. Are there any consistent gaps?

# %%
company_df = df[df['Company'] == 'ADBL'].copy()
company_df = company_df.sort_values(by='published_date')

plt.figure(figsize=(12, 6))
plt.plot(company_df['published_date'], company_df['open'], label='Open Price', color='green')
plt.plot(company_df['published_date'], company_df['close'], label='Close Price', color='yellow')
plt.title('Open vs Close Price Over Time - ADBL')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the trend of per_change (percent change) over time? Are there any highly volatile periods?

# %%
company_df = company_df.sort_values(by='published_date')

plt.figure(figsize=(12, 6))
plt.plot(company_df['published_date'], company_df['per_change'], label='Close Price', color='red')
plt.title('Percentage change Over Time')
plt.xlabel('Date')
plt.ylabel('Percentage change')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df= df.sort_values('published_date')
plt.figure(figsize=(12, 6))
plt.plot(df['published_date'], df['per_change'], color='brown', alpha=0.6)
plt.title('Percent Change (per_change) Over Time')
plt.xlabel('Date')
plt.ylabel('Percent Change')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the traded_quantity and traded_amount over time. Are there spikes that suggest unusually high trading activity?

# %%
plt.figure(figsize=(14, 6))
plt.plot(df['published_date'], df['traded_quantity'], label='Traded Quantity', color='green', alpha=1)

plt.plot(df['published_date'], df['traded_amount'], label='Traded Amount', color='purple', alpha=0.5)

plt.title('Traded Quantity and Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Create a multi-line plot for close prices of multiple companies. How do their trends compare over the same time period?

# %%
pivot_df = df.pivot_table(index='published_date', columns='Company', values='close')

selected_companies = ['ADBL', 'UPPER', 'KBL', 'NIFRA', 'HPPL']
pivot_df[selected_companies].plot(figsize=(14, 6), linewidth=1.2)

plt.title('Close Prices Over Time  Multiple Companies')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.legend(title='Company')
plt.tight_layout()
plt.show()

# %% [markdown]
# # How does the closing price behave across months or years?

# %%
df['year'] = df['published_date'].dt.year

yearly_close = df.groupby('year')['close'].mean()
monthly_close = df.groupby('month')['close'].mean()

plt.figure(figsize=(10, 5))
yearly_close.plot(marker='o')
plt.title('Average Closing Price by Year')
plt.xlabel('Year')
plt.ylabel('Average Close Price')
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
monthly_close.plot(marker='o', color='green')
plt.title('Average Closing Price by Month (All Years)')
plt.xlabel('Month')
plt.ylabel('Average Close Price')
plt.grid(True)
plt.tight_layout()
plt.show()
